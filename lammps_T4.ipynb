# %% [markdown]
# <a href="https://colab.research.google.com/github/HrishiHarsora/MSE203-Assignment-1-/blob/main/lammps_T4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd mylammps
# !rm -rf build
# !mkdir build
# %cd build

# !cmake ../cmake \
    -D PKG_GPU=ON \
    -D GPU_API=cuda \
    -D GPU_ARCH=sm_75 \
    -D PKG_KMC=ON \
    -D PKG_EXTRA_FIX=ON \
    -D PKG_MANYBODY=ON \
    -D PKG_MC=ON \
    -D BUILD_MPI=ON \
    -D CMAKE_INSTALL_PREFIX=/usr/local \
    -D CMAKE_BUILD_TYPE=Release

# !cmake --build . -j$(nproc)

# %cd ../../
# !ls

# %%
# %cd mylammps/build
# !make -j$(nproc)
# !make install
# %cd ../../

# %%
# !lmp -h

# %%
# !mpirun --allow-run-as-root --oversubscribe -np 2 lmp -sf gpu -pk gpu 1 -in md.in
